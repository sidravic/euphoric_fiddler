# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
import os

# %%
folder_name = 'fd7bf4b5-c8c6-4e78-9adb-ebe49c4fcefd'
root_images_dir = '/home/sidravic/downloaded_images/v1'

empty_img = '0.jpg'
valid_img = '1.jpg'
png_img = '03.png'

# %%
valid_image_path = root_images_dir + '/' + folder_name + '/' + valid_img
empty_image_path = root_images_dir + '/' + folder_name + '/' + empty_img
png_image_path = root_images_dir + '/' + folder_name + '/' + png_img

valid_image_path
# Out:
# '/home/sidravic/downloaded_images/v1/fd7bf4b5-c8c6-4e78-9adb-ebe49c4fcefd/1.jpg'

# %%
v = Image.open(valid_image_path)
plt.imshow(v)
plt.axis('off')
# Out:
# (-0.5, 299.5, 199.5, -0.5)

# %%
v.get_format_mimetype()
# Out:
# 'image/jpeg'

# %%
v.format
# Out:
# 'JPEG'

# %%
png_image_path = '/home/sidravic/downloaded_images/v1/ffdb16f2-9cc4-41ab-bd8b-b7d3da605374/wk3318_Becca_Ultimate_Coverage_Hero_d.png'
v2 = Image.open(png_image_path)
plt.imshow(v2)
plt.axis('off')
# Out:
# (-0.5, 899.5, 719.5, -0.5)

# %%
v2.format
# Out:
# 'PNG'

# %%
v2.size
# Out:
# (900, 720)

# %%
png_image = v2

# %%
jpg_img = png_image.convert('RGB')
jpg_img.save('jpg_converted_png.jpg')

# %%
plt.imshow(jpg_img)

# %%
bg = Image.new('RGBA', png_image.size, (255, 255, 255))
png = png_image.convert('RGBA')
bg.paste(png, png.size, png)
bg.save('bg.jpg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Dropbox/code/workspace/rails_apps/idylmynds/data_preprocessing/venv/lib/python3.6/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     618     try:
# --> 619         rawmode = RAWMODE[im.mode]
#     620     except KeyError:
#
# KeyError: 'RGBA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-54-9164512f7855> in <module>
#       2 png = png_image.convert('RGBA')
#       3 bg.paste(png, png.size, png)
# ----> 4 bg.save('bg.jpg')
#
# ~/Dropbox/code/workspace/rails_apps/idylmynds/data_preprocessing/venv/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2082
#    2083         try:
# -> 2084             save_handler(self, fp, filename)
#    2085         finally:
# ...

# %%
plt.imshow(bg)

# %%
x = '/home/sidravic/downloaded_images/v1/a2f576d3-60d4-43f9-83b5-7b22f0a34ceb'

# %%
x.split('/')[-1]
# Out:
# 'a2f576d3-60d4-43f9-83b5-7b22f0a34ceb'

# %%
i = Image.open('/home/sidravic/downloaded_images/v1/baf-8c18-4e90-8bdf67c31-1ac2f8416c21/BC_105210_800x800_5.gif')

# %%
plt.imshow(i)

# %%
i.get_format_mimetype()
# Out:
# 'image/jpeg'
